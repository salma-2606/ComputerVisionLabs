# %% [markdown]
# ## Image and Video Detection using YOLO

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# Load the YOLO model
model = YOLO('../yolov8n.pt')

# %%
# Image detection
image_path = 'input_image.jpeg'  
results = model(source=image_path, show=True, conf=0.4, save=True)
# Out:
# image 1/1 C:\Users\user\Computer vision labs\Task 5\input_image.jpeg: 640x448 13 persons, 1 cup, 1 chair, 5 laptops, 188.3ms
# Speed: 8.0ms preprocess, 188.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs\detect\predict3

# %%
# Video detection
video_path = 'input_video.mp4'  
cap = cv2.VideoCapture(video_path) # to read the input video
output_path = 'output_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v') 
# extract video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
# set up cv2.VideoWriter with these properties to ensure the output video matches the input video’s format.
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# processes a video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    results = model(frame)
    annotated_frame = results[0].plot()  # Annotate frame
    out.write(annotated_frame)
    cv2.imshow('YOLO Detection', annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 1 couch, 1 bed, 157.7ms
# Speed: 2.0ms preprocess, 157.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 152.6ms
# Speed: 1.5ms preprocess, 152.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 2 beds, 121.5ms
# Speed: 1.5ms preprocess, 121.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 2 beds, 94.0ms
# Speed: 1.9ms preprocess, 94.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 2 beds, 87.6ms
# Speed: 3.1ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 2 beds, 90.5ms
# Speed: 1.4ms preprocess, 90.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 1 bed, 122.7ms
# Speed: 1.7ms preprocess, 122.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 1 bed, 121.7ms
# Speed: 2.6ms preprocess, 121.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 1 bed, 119.5ms
# Speed: 0.0ms preprocess, 119.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 beds, 95.6ms
# Speed: 3.1ms preprocess, 95.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 couch, 2 beds, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 1 bed, 1 teddy bear, 94.7ms
# Speed: 0.0ms preprocess, 94.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 couch, 127.4ms
# Speed: 1.3ms preprocess, 127.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 couch, 1 bed, 159.2ms
# Speed: 4.5ms preprocess, 159.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 138.2ms
# Speed: 6.2ms preprocess, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 2 beds, 90.1ms
# Speed: 1.2ms preprocess, 90.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 88.5ms
# Speed: 2.9ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 2 beds, 111.3ms
# Speed: 2.4ms preprocess, 111.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 beds, 96.6ms
# Speed: 5.8ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 1 teddy bear, 118.3ms
# Speed: 7.1ms preprocess, 118.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 1 teddy bear, 126.9ms
# Speed: 0.0ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 77.2ms
# Speed: 0.0ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 111.8ms
# Speed: 2.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 1 teddy bear, 108.7ms
# Speed: 0.0ms preprocess, 108.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 1 teddy bear, 118.2ms
# Speed: 10.9ms preprocess, 118.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 130.2ms
# Speed: 2.9ms preprocess, 130.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 86.5ms
# Speed: 0.0ms preprocess, 86.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 144.6ms
# Speed: 0.0ms preprocess, 144.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 couch, 1 bed, 99.9ms
# Speed: 3.9ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 couch, 1 bed, 105.3ms
# Speed: 0.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 113.3ms
# Speed: 2.5ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 126.6ms
# Speed: 0.0ms preprocess, 126.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 1 refrigerator, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 94.2ms
# Speed: 1.9ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 87.4ms
# Speed: 6.1ms preprocess, 87.4ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 95.9ms
# Speed: 2.2ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 128.6ms
# Speed: 0.0ms preprocess, 128.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 97.7ms
# Speed: 5.5ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 63.0ms
# Speed: 2.7ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 84.9ms
# Speed: 9.9ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 110.0ms
# Speed: 4.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 1 teddy bear, 169.4ms
# Speed: 2.9ms preprocess, 169.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 1 teddy bear, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 1 teddy bear, 99.7ms
# Speed: 6.5ms preprocess, 99.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 1 teddy bear, 102.1ms
# Speed: 8.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 beds, 1 teddy bear, 99.0ms
# Speed: 3.6ms preprocess, 99.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds,
8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 dog, 2 books, 101.5ms
# Speed: 3.2ms preprocess, 101.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 dog, 1 bed, 4 books, 107.6ms
# Speed: 2.2ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cat, 1 dog, 1 bed, 3 books, 91.4ms
# Speed: 10.2ms preprocess, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cat, 1 dog, 2 books, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 book, 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 book, 90.2ms
# Speed: 6.7ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 2 books, 98.4ms
# Speed: 4.9ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 1 book, 80.7ms
# Speed: 1.6ms preprocess, 80.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 bed, 1 book, 95.1ms
# Speed: 3.7ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 2 books, 80.9ms
# Speed: 2.4ms preprocess, 80.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 couch, 1 bed, 1 book, 86.9ms
# Speed: 5.5ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 book, 87.1ms
# Speed: 3.9ms preprocess, 87.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 bed, 1 book, 97.1ms
# Speed: 0.0ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 2 books, 76.9ms
# Speed: 0.0ms preprocess, 76.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 60.4ms
# Speed: 1.4ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.4ms
# Speed: 2.2ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cat, 81.6ms
# Speed: 2.0ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 83.7ms
# Speed: 17.2ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 82.0ms
# Speed: 3.2ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 91.3ms
# Speed: 2.1ms preprocess, 91.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 102.6ms
# Speed: 4.3ms preprocess, 102.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 86.1ms
# Speed: 6.0ms preprocess, 86.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 86.9ms
# Speed: 15.7ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 80.6ms
# Speed: 2.1ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.4ms
# Speed: 8.5ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 tie, 81.0ms
# Speed: 8.2ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 dog, 1 tie, 102.5ms
# Speed: 15.7ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tie, 78.2ms
# Speed: 10.5ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 dog, 71.4ms
# Speed: 4.2ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 dog, 1 teddy bear, 80.4ms
# Speed: 5.1ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 97.6ms
# Speed: 4.8ms preprocess, 97.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 10.0ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 93.0ms
# Speed: 18.4ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.7ms
# Speed: 2.7ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.1ms
# Speed: 6.7ms preprocess, 82.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 donut, 96.4ms
# Speed: 4.2ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 teddy bears, 82.4ms
# Speed: 3.6ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 1 teddy bear, 81.9ms
# Speed: 10.4ms preprocess, 81.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 83.6ms
# Speed: 15.7ms preprocess, 83.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 91.8ms
# Speed: 5.5ms preprocess, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 95.3ms
# Speed: 6.5ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 80.5ms
# Speed: 12.5ms preprocess, 80.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.1ms
# Speed: 6.2ms preprocess, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 dog, 1 cup, 80.6ms
# Speed: 0.0ms preprocess, 80.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.3ms
# Speed: 1.2ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 102.5ms
# Speed: 6.6ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 1 teddy bear, 73.6ms
# Speed: 0.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 persons, 1 dog, 87.8ms
# Speed: 4.5ms preprocess, 87.8ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 dog, 84.3ms
# Speed: 6.2ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 cup, 94.5ms
# Speed: 15.5ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.4ms
# Speed: 4.0ms preprocess, 94.4ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 117.4ms
# Speed: 2.4ms preprocess, 117.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cat, 1 dog, 1 handbag, 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 84.1ms
# Speed: 1.6ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 74.9ms
# Speed: 4.3ms preprocess, 74.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 chair, 78.4ms
# Speed: 2.7ms preprocess, 78.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 chair, 98.4ms
# Speed: 0.0ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 chair, 97.1ms
# Speed: 8.6ms preprocess, 97.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 83.2ms
# Speed: 15.6ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 86.7ms
# Speed: 3.5ms preprocess, 86.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 223.5ms
# Speed: 17.9ms preprocess, 223.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 114.1ms
# Speed: 3.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 99.6ms
# Speed: 0.0ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 122.0ms
# Speed: 4.0ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 101.6ms
# Speed: 10.3ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 86.2ms
# Speed: 10.1ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 teddy bear, 92.7ms
# Speed: 0.0ms preprocess, 92.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 teddy bear, 100.8ms
# Speed: 1.6ms preprocess, 100.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 110.2ms
# Speed: 7.0ms preprocess, 110.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 suitcase, 84.1ms
# Speed: 8.3ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 suitcase, 79.0ms
# Speed: 2.4ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tie, 74.3ms
# Speed: 0.0ms preprocess, 74.3ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 92.5ms
# Speed: 2.6ms preprocess, 92.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 121.4ms
# Speed: 0.0ms preprocess, 121.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 119.5ms
# Speed: 2.5ms preprocess, 119.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 115.6ms
# Speed: 0.0ms preprocess, 115.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 79.8ms
# Speed: 2.9ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 dog, 1 couch, 109.3ms
# Speed: 3.3ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 95.8ms
# Speed: 15.6ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 85.3ms
# Speed: 2.9ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 102.3ms
# Speed: 6.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 couch, 90.9ms
# Speed: 5.0ms preprocess, 90.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 tie, 89.0ms
# Speed: 3.9ms preprocess, 89.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 83.4ms
# Speed: 7.0ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 couch, 1 bed, 81.9ms
# Speed: 7.1ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 dog, 1 bed, 82.8ms
# Speed: 4.7ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 1 bed, 114.4ms
# Speed: 7.2ms preprocess, 114.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 90.2ms
# Speed: 2.5ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 dogs, 1 bed, 91.3ms
# Speed: 7.6ms preprocess, 91.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 1 bed, 113.9ms
# Speed: 3.4ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 1 bed, 85.7ms
# Speed: 3.1ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 1 bed, 67.3ms
# Speed: 2.6ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 1 bed, 97.2ms
# Speed: 5.4ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 bed, 82.6ms
# Speed: 6.9ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 bed, 71.9ms
# Speed: 2.0ms preprocess, 71.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 2 dogs, 140.7ms
# Speed: 7.0ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 bed, 69.6ms
# Speed: 13.4ms preprocess, 69.6ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 82.6ms
# Speed: 0.0ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 dog, 1 bed, 108.6ms
# Speed: 10.1ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 86.0ms
# Speed: 12.7ms preprocess, 86.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 dog, 1 bed, 79.8ms
# Speed: 6.9ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 119.0ms
# Speed: 5.1ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 dog, 1 bed, 88.6ms
# Speed: 7.1ms preprocess, 88.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 bed, 72.1ms
# Speed: 10.7ms preprocess, 72.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 bed, 80.9ms
# Speed: 2.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 cat, 1 dog, 1 bed, 117.5ms
# Speed: 3.0ms preprocess, 117.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 95.0ms
# Speed: 12.4ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 93.8ms
# Speed: 3.4ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 bed, 104.3ms
# Speed: 3.1ms preprocess, 104.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 2 dogs, 1 bed, 117.9ms
# Speed: 5.0ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 138.8ms
# Speed: 3.6ms preprocess, 138.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 103.5ms
# Speed: 3.5ms preprocess, 103.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 84.3ms
# Speed: 7.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 103.3ms
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 110.6ms
# Speed: 5.1ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 90.6ms
# Speed: 6.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 95.9ms
# Speed: 2.5ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 couch, 1 bed, 88.8ms
# Speed: 9.2ms preprocess, 88.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 bed, 112.0ms
# Speed: 3.3ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 couch, 1 bed, 110.3ms
# Speed: 6.7ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 couch, 1 bed, 80.1ms
# Speed: 2.5ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 dogs, 1 couch, 1 bed, 92.0ms
# Speed: 3.0ms preprocess, 92.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 couch, 1 bed, 94.6ms
# Speed: 9.2ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 couch, 1 bed, 1 book, 97.5ms
# Speed: 5.6ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 couch, 2 beds, 85.0ms
# Speed: 3.0ms preprocess, 85.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 couch, 1 bed, 114.1ms
# Speed: 3.3ms preprocess, 114.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 101.9ms
# Speed: 4.6ms preprocess, 101.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 1 book, 88.5ms
# Speed: 12.1ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 3 books, 100.7ms
# Speed: 7.1ms preprocess, 100.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 2 beds, 2 books, 87.1ms
# Speed: 7.1ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 2 beds, 91.1ms
# Speed: 3.0ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed, 98.3ms
# Speed: 7.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 94.4ms
# Speed: 2.4ms preprocess, 94.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 89.9ms
# Speed: 5.1ms preprocess, 89.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 2 beds, 83.5ms
# Speed: 1.3ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 116.9ms
# Speed: 4.2ms preprocess, 116.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 120.9ms
# Speed: 3.5ms preprocess, 120.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 1 bed, 1 book, 94.2ms
# Speed: 3.7ms preprocess, 94.2ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 bed,
7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 141.4ms
# Speed: 0.0ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 173.8ms
# Speed: 0.0ms preprocess, 173.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.9ms
# Speed: 4.1ms preprocess, 74.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.5ms
# Speed: 0.0ms preprocess, 163.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# This **while** block processes a video frame by frame using YOLO, annotates each frame with detection results, and writes the annotated frames into an output video. It also displays the results in a real-time OpenCV window.
#
# ---
#
# ### **1. `while cap.isOpened():`**
# - **Purpose**: Keeps processing frames as long as the video file or camera feed (`cap`) is open and functional.
# - **`cap.isOpened()`**: Returns `True` if the video capture object (`cap`) is successfully opened.
#
# ---
#
# ### **2. `ret, frame = cap.read()`**
# - **Purpose**: Reads the next frame from the video stream.
# - **`cap.read()`**:
#   - Returns two values:
#     - `ret`: A boolean indicating if the frame was successfully read (`True` for success, `False` if there are no more frames or an error occurs).
#     - `frame`: The actual video frame as a NumPy array.
#
# ---
#
# ### **3. `if not ret: break`**
# - **Purpose**: Exits the loop if no frame is read (e.g., end of the video).
# - **`not ret`**: Checks if `ret` is `False`, signaling that the video has no more frames or an error occurred.
#
# ---
#
# ### **4. `results = model(frame)`**
# - **Purpose**: Passes the current video frame to the YOLO model for object detection or segmentation.
# - **`model(frame)`**:
#   - Processes the frame with YOLO to generate detection results.
#   - `results` contains:
#     - Detected objects' bounding boxes.
#     - Class labels.
#     - Confidence scores (and masks, for segmentation).
#
# ---
#
# ### **5. `annotated_frame = results[0].plot()`**
# - **Purpose**: Visualizes the YOLO detection results on the frame.
# - **`results[0]`**: Accesses the first result (YOLO supports batch processing, but typically a single frame is processed at a time in videos).
# - **`.plot()`**: Annotates the frame with bounding boxes, class names, and other detection information.
#
# ---
#
# ### **6. `out.write(annotated_frame)`**
# - **Purpose**: Writes the annotated frame to the output video file.
# - **`out.write()`**: Appends the frame to the video being saved.
# - **`annotated_frame`**: The frame with YOLO-detected objects drawn on it.
#
# ---
#
# ### **7. `cv2.imshow('YOLO Detection', annotated_frame)`**
# - **Purpose**: Displays the annotated frame in a real-time OpenCV window titled `'YOLO Detection'`.
# - **`cv2.imshow()`**: Opens a window to show the processed frame.
#
# ---
#
# ### **8. `if cv2.waitKey(1) & 0xFF == ord('q'):`**
# - **Purpose**: Allows the user to exit the video display by pressing the `q` key.
# - **`cv2.waitKey(1)`**:
#   - Waits for 1 millisecond for a key press.
#   - Returns a code for the pressed key.
# - **`& 0xFF`**: Ensures compatibility across platforms by masking unwanted bits.
# - **`ord('q')`**: Converts the character `'q'` to its ASCII value for comparison.
#
# ---
#
# ### **9. `cap.release()`**
# - **Purpose**: Releases the video capture object (`cap`) and frees associated resources.
#
# ---
#
# ### **10. `out.release()`**
# - **Purpose**: Closes the video writer (`out`) and saves the output video file.
#
# ---
#
# ### **11. `cv2.destroyAllWindows()`**
# - **Purpose**: Closes all OpenCV display windows to clean up after the program ends.
#
# ---
#
# ### **Summary of the Workflow**
# 1. Reads video frames one by one.
# 2. Runs YOLO detection or segmentation on each frame.
# 3. Annotates the frame with results.
# 4. Writes the annotated frame to an output video file.
# 5. Displays the annotated frame in real time.
# 6. Exits on `q` key press or when the video ends.
#
# This block is crucial for real-time video processing and output generation using YOLO. Let me know if you'd like me to elaborate further!
